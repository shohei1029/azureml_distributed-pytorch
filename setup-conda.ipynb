# %% [markdown]
# # 事前準備
# ## Conda 環境の構築
# クライアントPCにでconda環境を作成します。予めMinicondaやAnacondaがインストールされている前提です。
# ※ファイルパスはリポジトリ直下を起点としています。

# %% [markdown]
# yamlファイルに記載しているパッケージをベースに conda 環境 (pytorch_env) を作成

# %%
# !conda env create -n "pytorch_env" -f ./examples/distributed-pytorch-with-distributeddataparallel.yml
# Out:
# ...
# Solving environment: -
# ...
#   - defaults/linux-64::jedi-0.17.0-py36_0, defaults/noarch::parso-0.8.1-pyhd3eb1b0_0
#   - defaults/linux-64::jedi-0.17.2-py36h06a4308_1, defaults/noarch::parso-0.7.0-pydone
#
# ...
# certifi-2020.12.5    | 140 KB    | ##################################### | 100%
# defusedxml-0.7.1     | 23 KB     | ##################################### | 100%
# pip-21.0.1           | 1.8 MB    | ##################################### | 100%
# python-3.6.13        | 29.7 MB   | ##################################### | 100%
# jedi-0.17.0          | 780 KB    | ##################################### | 100%
# ipython-7.16.1       | 999 KB    | ##################################### | 100%
# async_generator-1.10 | 39 KB     | ##################################### | 100%
# argon2-cffi-20.1.0   | 46 KB     | ##################################### | 100%
# nbconvert-6.0.7      | 480 KB    | ##################################### | 100%
# ...

# %%
#確認
# !conda info -e
# Out:
# # conda environments:
# #
# base                  *  /home/shohei/.anyenv/envs/pyenv/versions/anaconda3-2020.11
# pytorch_env              /home/shohei/.anyenv/envs/pyenv/versions/anaconda3-2020.11/envs/pytorch_env

# %%
#削除用
#!conda remove -n "pytorch_env" --all -y

# %% [markdown]
# ## Azure ML ワークスペース情報の取得
